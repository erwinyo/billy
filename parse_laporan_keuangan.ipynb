# %%
import pandas as pd

# %%
# Load an Excel file (replace 'your_file.xlsx' with your actual file name)
df = pd.read_excel('Laporan Keuangan 2025.xlsx')
df.
# Out:
#         SOMETHING YOU CREDITED Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       AMOUNT   INVESTOR   RESERVED        NaN       PAID
# 1                          NaN        NaN      MONTH     ISSUED       DATE
# 2                            0        NaN        NaN        NaN        NaN
# 3                          NaN        NaN        NaN        NaN        NaN
# 4                          NaN        NaN        NaN        NaN        NaN
# 5                          NaN        NaN        NaN        NaN        NaN
# 6                          NaN        NaN        NaN        NaN        NaN
# 7                          NaN        NaN        NaN        NaN        NaN
# 8                          NaN        NaN        NaN        NaN        NaN
# 9                          NaN        NaN        NaN        NaN        NaN
# 10                         NaN        NaN        NaN        NaN        NaN
# ...
